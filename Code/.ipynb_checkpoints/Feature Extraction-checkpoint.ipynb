# %%
import os
import re

import tensorflow as tf
import tensorflow.python.platform
from tensorflow.python.platform import gfile
import numpy as np
import pandas as pd
import sklearn
from sklearn import cross_validation
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.svm import SVC, LinearSVC
import matplotlib.pyplot as plt
# %matplotlib inline
import pickle

# %%
class extractFeatures:
    def __init__(self,model_path,images_dir):
        self.model = model_path
        self.list_images = [images_dir+f for f in os.listdir(images_dir) if re.search('jpg|JPG', f)]
        
    def create_graph():
        with gfile.FastGFile(os.path.join(model_dir, self.model), 'rb') as f:
            graph_def = tf.GraphDef()
            graph_def.ParseFromString(f.read())
            _ = tf.import_graph_def(graph_def, name='')

    def extract_features():
        nb_features = 2048
        features = np.empty((len(self.list_images),nb_features))
        labels = []
        create_graph()
        with tf.Session() as sess:
            next_to_last_tensor = sess.graph.get_tensor_by_name('pool_3:0')
            for ind, image in enumerate(list_images):
                if (ind%100 == 0):
                    print('Processing %s...' % (image))
                if not gfile.Exists(image):
                    tf.logging.fatal('File does not exist %s', image)
                    continue

                image_data = gfile.FastGFile(image, 'rb').read()
                predictions = sess.run(next_to_last_tensor,{'DecodeJpeg/contents:0': image_data})
                features[ind,:] = np.squeeze(predictions)
                labels.append(re.split('_\d+',image.split('/')[1])[0])

        return features, labels

# %%
model_dir = '/home/saharsh/Documents/imagenet/'
images_dir = '/home/saharsh/Documents/imagenet/'
list_images = [images_dir+f for f in os.listdir(images_dir) if re.search('jpg|JPG', f)]

# %%
def create_graph():
    with gfile.FastGFile(os.path.join(
        model_dir, 'classify_image_graph_def.pb'), 'rb') as f:
        graph_def = tf.GraphDef()
        graph_def.ParseFromString(f.read())
        _ = tf.import_graph_def(graph_def, name='')

# %%
def extract_features(list_images):
    
    nb_features = 2048
    features = np.empty((len(list_images),nb_features))
    labels = []
    create_graph()

    with tf.Session() as sess:
        print sess.graph.get_operations().op()
#         next_to_last_tensor = sess.graph.get_tensor_by_name('pool_3:0')
#         for ind, image in enumerate(list_images):
#             if (ind%100 == 0):
#                 print('Processing %s...' % (image))
#             if not gfile.Exists(image):
#                 tf.logging.fatal('File does not exist %s', image)
#                 continue
                
#             image_data = gfile.FastGFile(image, 'rb').read()
#             predictions = sess.run(next_to_last_tensor,{'DecodeJpeg/contents:0': image_data})
#             features[ind,:] = np.squeeze(predictions)
#             labels.append(re.split('_\d+',image.split('/')[1])[0])

#    return features, labels

# %%
features,labels = extract_features(list_images)
# Out:
# [<tensorflow.python.framework.ops.Operation object at 0x7ffb7f64ee10>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f64ee90>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f64edd0>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f64ee50>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f65e610>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f65e6d0>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f65eb90>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f65e650>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f65ed50>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f65ec50>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f5f2310>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f5f2450>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f5f2850>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f5f2a90>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f5f2510>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f5f2a50>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f5f2a10>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f602050>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f6021d0>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f602110>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f6025d0>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f602dd0>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f614110>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f614390>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f6143d0>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f614350>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f614250>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f614310>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f614c10>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f614ed0>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f6149d0>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f6256d0>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f625a50>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f625c90>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f625890>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f625c50>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f625c10>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f625bd0>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f5b67d0>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f5b6250>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f5b6310>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f5c8050>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f5c82d0>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f5c8610>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f5c8790>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f5c86d0>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f5c8cd0>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f5c8810>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f5c8c90>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f5c8c50>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f5c8c10>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f5d7810>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f5d7290>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f5d7350>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f5ea090>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f5ea390>, <tensorflow.python.framework.ops.Operation object at 0x7ffb7f5ea5d0>, <tensorfl ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-b52438a12cd5> in <module>()
# ----> 1 features,labels = extract_features(list_images)
#
# TypeError: 'NoneType' object is not iterable

# %%
print features.shape
# Out:
# (1, 2048)

# %%
#plt.plot(range(0,features.shape[1]), features)
print features
plt.plot(range(0,features.shape[1]),features[0])
plt.show()
# Out:
# [[ 0.19233467  0.04197577  0.14644754 ...,  0.11446106  0.01030327
#    0.1371786 ]]
